# %%
# %pip install -q pandas openpyxl
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

import pandas as pd

import Tratar_dados.limpar_Texto as lt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv(r'/workspaces/Series_Temporais/Data/daily-minimum-temperatures-in-me.csv', sep = ',')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        3650 non-null   str
#  1   Daily minimum temperatures  3650 non-null   str
# dtypes: str(2)
# memory usage: 57.2 KB

# %%
df = lt.limpar_Texto(df)

df = lt.converter_tipo_coluna(df)

# %%
display(df)
# Out:
#             Daily minimum temperatures
# Date
# 1981-01-01                        20.7
# 1981-01-02                        17.9
# 1981-01-03                        18.8
# 1981-01-04                        14.6
# 1981-01-05                        15.8
# ...                                ...
# 1990-12-27                        14.0
# 1990-12-28                        13.6
# 1990-12-29                        13.5
# 1990-12-30                        15.7
# 1990-12-31                        13.0
#
# [3650 rows x 1 columns]
